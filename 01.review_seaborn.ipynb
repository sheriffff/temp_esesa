# %% [markdown]
# # Visualización de datos: práctica y ejercicios

# %% [markdown]
# **NOTAS**
#  - Hay muchas formas de resolver cada problema, encuentra la tuya.
#  - Crea las celdas extra que necesites.
#  - Recuerda que una celda puede ser de tipo Código, o de tipo Markdown. Utiliza las segundas para escribir texto y explicaciones si lo precisas.
#  - Intenta crear variables a la hora de resolver los ejercicios.
#  - Puedes apoyarte en internet: todos los programadores lo hacemos a diario.

# %% [markdown]
# <img width=500 src="https://www.thestatesman.com/wp-content/uploads/2018/04/Penguins.jpg">

# %% [markdown]
# Importamos la librería `seaborn`
#
# Importamos el dataset *penguins*: cada fila es un pinguino observado en una expedición

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [3, 2]

# %%
df = sns.load_dataset("penguins")

# %% [markdown]
#  - Intenta dar solución tanto analítica como gráfica a las preguntas
#  - Intenta utilizar colores apropiados y coherentes durante la resolución de los ejercicios

# %% [markdown]
# Echa un vistazo a las primeras filas del dataframe

# %%
df.shape
# Out:
# (344, 7)

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Cuántos pinguinos hay de cada especie?

# %%
sns.countplot(x=df.species)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# Cuántos pinguinos hay en cada isla?

# %%
sns.countplot(x=df.island)
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# Cuántos pinguinos de cada especie hay en cada isla?

# %%
import pandas as pd

# %%
dff = pd.read_csv("./datasets/titanic.csv")

# %%
dff.head()
# Out:
#                       Name     Sex   Age  Pclass  SibSp  Parch       Ticket  \
# 0        Karaic, Mr. Milan    male  30.0       3      0      0       349246
# 1       Dean, Mrs. Bertram  female  33.0       3      1      2    C.A. 2315
# 2       Rice, Mrs. William  female  39.0       3      0      5       382652
# 3  Davidson, Mrs. Thornton  female  27.0       1      1      2   F.C. 12750
# 4     Ridsdale, Miss. Lucy  female  50.0       2      0      0  W./C. 14258
#
#       Fare Cabin Embarked  Survived
# 0   7.8958   NaN        S         0
# 1  20.5750   NaN        S         1
# 2  29.1250   NaN        Q         0
# 3  52.0000   B71        S         1
# 4  10.5000   NaN        S         1

# %%
sns.countplot(x=df.island, hue=df.species, palette="Set2")
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# Hay más machos o hembras pinguinos?

# %%
sns.countplot(x=df.sex)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# Y en cada isla?

# %%
sns.countplot(hue=df.sex, x=df.island, palette=[(169 / 255, 90 / 255, 61 / 255), (10 / 255, 10 / 255, 201 / 255)])
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# Cómo se distribuye el peso de los pinguinos?

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.histplot(x=df.body_mass_g)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# Cómo se distribuye el largo del pico de los pinguinos?

# %% [markdown]
# Cómo se distribuye el peso de los pinguinos por especie?

# %%
sns.kdeplot(x=df.body_mass_g, hue=df.species)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# Cuál es la mediana del peso de los pinguinos?

# %%
df.body_mass_g.median().round()
# Out:
# 4050.0

# %%
sns.boxplot(x=df.body_mass_g)
# Out:
# <Axes: xlabel='body_mass_g'>

# %% [markdown]
# Y por especie?

# %%
df.groupby("species").body_mass_g.median().round()
# Out:
# species
# Adelie       3700.0
# Chinstrap    3700.0
# Gentoo       5000.0
# Name: body_mass_g, dtype: float64

# %%
sns.boxplot(x=df.body_mass_g, hue=df.species)
# if not, try
# sns.boxplot(x=df.body_mass_g, y=df.species)
# Out:
# <Axes: xlabel='body_mass_g'>

# %% [markdown]
# Qué gráfica utilizarías para ver lo anterior?

# %% [markdown]
# Boxplot

# %% [markdown]
# Las aletas (flipper), las tienen mayores machos o hembras?

# %%
sns.kdeplot(x=df.flipper_length_mm, hue=df.sex)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %% [markdown]
# Cómo se relaciona el peso con la bill depth? Evalúalo con una gráfica y calculando la correlación

# %%
sns.scatterplot(x=df.bill_depth_mm, y=df.body_mass_g)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %% [markdown]
# <img width=400 src="https://bookdown.org/curleyjp0/psy317l_guides5/img/correlations.png">

# %% [markdown]
# *Lo mismo que antes, pero por especie. Qué observas? [Paradoja de Simpson](https://en.wikipedia.org/wiki/Simpson%27s_paradox)

# %%
sns.scatterplot(x=df.bill_depth_mm, y=df.body_mass_g, hue=df.species)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %% [markdown]
# Muestra la tabla de correlación para cada par de variables numéricas

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df[['bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g']].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.pairplot(df, hue="species")

# %%
sns.jointplot(x=df.bill_depth_mm, y=df.body_mass_g, hue=df.species)

# %% [markdown]
# Haz un gráfico de tu elección con 2 variables numéricas y 2 categóricas (pista: usa `hue` y `style`). Te resulta útil?

# %%
sns.jointplot(x=df.bill_depth_mm, y=df.body_mass_g, hue=df.species, style=df.island)
